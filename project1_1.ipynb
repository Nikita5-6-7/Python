# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikita5-6-7/Python/blob/main/project1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
string1 = input("Please enter a string value1:")
string2=input("Please enter a string value2:")
int1 = int(input("Please enter an integer value1: "))
int2 = int(input("Please enter an integer value2: "))

name = string1 + " " + string2
print("My name is " + name + ".")

print(len(name))

sum_number= int1 + int2
mul_number = int1 * int2
if int1 > int2:
  print("True: int1 is grater than int2")
else:
  print("False: int2 is grater than int1")

print(f"Addition: {sum_number} ")
print(f"Multiplication: {mul_number} ")

print(type(string1),type(string2),type(int1), type(int2))
# Out:
# Please enter a string value1:Nikita
# Please enter a string value2:Patel
# Please enter an integer value1: 20
# Please enter an integer value2: 10
# My name is Nikita Patel.
# 12
# True: int1 is grater than int2
# Addition: 30
# Multiplication: 200
# <class 'str'> <class 'str'> <class 'int'> <class 'int'>

# %%
Full_name = {
    "FirstName" : "Nikita",
    "Latname" : "Patel"
}
print(Full_name.keys())
print(Full_name.values())
# Out:
# dict_keys(['FirstName', 'Latname'])
# dict_values(['Nikita', 'Patel'])

# %%
name = input("Enter your name:")
print("Hello " + name)
# Out:
# Enter your name:Nikkita
# Hello Nikkita

# %%
hours = int(input("Enter the hours:"))
rate = float(input("Enter the Rate:"))
pay = hours * rate
print(f"pay: {pay}")
# Out:
# Enter the hours:20
# Enter the Rate:17
# pay: 340.0
